# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("superstore.csv")
df.head()
# Out:
#   Order_ID  Order_Date         Category Sub_Category   Region    Sales  \
# 0   CA-001  2023-01-05        Furniture       Chairs     East   250.50
# 1   CA-002  2023-01-08       Technology       Phones     West   899.99
# 2   CA-003  2023-01-10  Office Supplies      Binders    South    45.20
# 3   CA-004  2023-01-12       Technology      Laptops  Central  1299.00
# 4   CA-005  2023-01-15        Furniture       Tables     East   450.75
#
#    Profit  Quantity
# 0    45.3         2
# 1   120.5         3
# 2    -5.4         5
# 3   250.0         2
# 4   -30.2         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      15 non-null     object
#  1   Order_Date    15 non-null     object
#  2   Category      15 non-null     object
#  3   Sub_Category  15 non-null     object
#  4   Region        15 non-null     object
#  5   Sales         15 non-null     float64
#  6   Profit        15 non-null     float64
#  7   Quantity      15 non-null     int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.1+ KB

# %%
df.groupby("Category")["Profit"].sum()
# Out:
# Category
# Furniture          100.1
# Office Supplies     40.1
# Technology         835.5
# Name: Profit, dtype: float64

# %%
df.groupby("Region")["Profit"].sum()
# Out:
# Region
# Central    342.0
# East       330.1
# South       77.6
# West       226.0
# Name: Profit, dtype: float64

# %%
profit_by_category = df.groupby("Category")["Profit"].sum()
profit_by_category
# Out:
# Category
# Furniture          100.1
# Office Supplies     40.1
# Technology         835.5
# Name: Profit, dtype: float64

# %%
profit_by_category.plot(kind="bar")
plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()

# %%
profit_by_region = df.groupby("Region")["Profit"].sum()

profit_by_region.plot(kind="bar", color="orange")
plt.title("Total Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")
plt.show()
